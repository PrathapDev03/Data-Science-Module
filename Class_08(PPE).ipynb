# %%
# !pip install ppscore
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 22.6 MB/s eta 0:00:00
# ...
#   Created wheel for ppscore: filename=ppscore-1.3.0-py2.py3-none-any.whl size=13164 sha256=6f62bb1fdd85a77c00a77d63f8de4dc9beb9f5c47a8875eea10c5e532c25b618
#   Stored in directory: /root/.cache/pip/wheels/42/87/10/00056aa2d2624f1b9374db6a0d5245da9a3d87bdc9247c1a56
# Successfully built ppscore
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# ...

# %%
import ppscore as pps
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/homes.csv')
df.head()
# Out:
#     "LivingArea"   "Rooms"   "Bedrooms"   "Bathrooms"   "Age"   "Acres"  \
# 0             28        10            5             3      60      0.28
# 1             18         8            4             1      12      0.43
# 2             13         6            3             1      41      0.33
# 3             17         7            3             1      22      0.46
# 4             25         8            4             3       5      2.05
#
#     "Price"
# 0     31670
# 1     40330
# 2     14710
# 3     32040
# 4     36130

# %%
df.columns
# Out:
# Index([' "LivingArea"', ' "Rooms"', ' "Bedrooms"', ' "Bathrooms"', ' "Age"',
#        ' "Acres"', ' "Price"'],
#       dtype='object')

# %%
pps.score(df,' "LivingArea"',' "Price"')
# Out:
# {'x': ' "LivingArea"',
#  'y': ' "Price"',
#  'ppscore': 0,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 7025.56,
#  'model_score': 9438.302884615387,
#  'model': DecisionTreeRegressor()}

# %%
pps.matrix(df)
# Out:
#                 x              y   ppscore            case  is_valid_score  \
# 0    "LivingArea"   "LivingArea"  1.000000  predict_itself            True
# 1    "LivingArea"        "Rooms"  0.000000      regression            True
# 2    "LivingArea"     "Bedrooms"  0.000000      regression            True
# 3    "LivingArea"    "Bathrooms"  0.000000      regression            True
# 4    "LivingArea"          "Age"  0.000000      regression            True
# 5    "LivingArea"        "Acres"  0.000000      regression            True
# 6    "LivingArea"        "Price"  0.000000      regression            True
# 7         "Rooms"   "LivingArea"  0.115079      regression            True
# 8         "Rooms"        "Rooms"  1.000000  predict_itself            True
# 9         "Rooms"     "Bedrooms"  0.145855      regression            True
# 10        "Rooms"    "Bathrooms"  0.000000      regression            True
# ...

# %%
pps.matrix(df).any()
# Out:
# x                 True
# y                 True
# ppscore           True
# case              True
# is_valid_score    True
# metric            True
# baseline_score    True
# model_score       True
# model             True
# dtype: bool

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pps_score = pps.matrix(df)[['x','y','ppscore']].pivot(columns='x',index='y',values='ppscore')

# %%
sns.heatmap(pps_score,annot=True,cmap='coolwarm')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
pps.predictors(df,' "Price"')
# Out:
#                x         y  ppscore        case  is_valid_score  \
# 0     "Bedrooms"   "Price"  0.00018  regression            True
# 1   "LivingArea"   "Price"  0.00000  regression            True
# 2        "Rooms"   "Price"  0.00000  regression            True
# 3    "Bathrooms"   "Price"  0.00000  regression            True
# 4          "Age"   "Price"  0.00000  regression            True
# 5        "Acres"   "Price"  0.00000  regression            True
#
#                 metric  baseline_score   model_score                    model
# 0  mean absolute error         7025.56   7024.296649  DecisionTreeRegressor()
# 1  mean absolute error         7025.56   9438.302885  DecisionTreeRegressor()
# 2  mean absolute error         7025.56   7564.995281  DecisionTreeRegressor()
# 3  mean absolute error         7025.56   7309.378535  DecisionTreeRegressor()
# 4  mean absolute error         7025.56  10926.484509  DecisionTreeRegressor()
# ...

# %%
sns.pairplot(df)
